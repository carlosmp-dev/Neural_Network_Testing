# %% [markdown]
# ## Definitions

# %%
#matplotlib inline
import os
import numpy as np
import pickle
import matplotlib.pyplot as plt

from keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from keras.optimizers import Adadelta, Adam, SGD
from keras.layers import Input, Conv2D, Dense, MaxPooling2D, Dropout, Flatten, AveragePooling2D, Conv2DTranspose, UpSampling2D, BatchNormalization
from keras.models import Sequential,
from keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from google.colab import drive
#drive.mount("/content/gdrive", force_remount=True)
#os.chdir("/content/gdrive/My Drive/Colab Notebooks") # might have to change path to point to your Colab Notebooks folder

# %% [markdown]
# ## Load and format data

# %%
data = np.load('./MNIST_CorrNoise.npz')

x_train = data['x_train']
y_train = data['y_train']

num_cls = len(np.unique(y_train))
print('Number of classes: ' + str(num_cls))

print('Example of handwritten digit with correlated noise: \n')

k = 3000
plt.imshow(np.squeeze(x_train[k,:,:]))
plt.show()
print('Class: '+str(y_train[k])+'\n')

# RESHAPE and standarize
x_train = np.expand_dims(x_train/255,axis=3)

# convert class vectors to binary class matrices
y_train = to_categorical(y_train, num_cls)

print('Shape of x_train: '+str(x_train.shape))
print('Shape of y_train: '+str(y_train.shape))
# Out:
# Number of classes: 10
# Example of handwritten digit with correlated noise:
# Class: 9
#
# Shape of x_train: (60000, 28, 28, 1)
# Shape of y_train: (60000, 10)

# %% [markdown]
# ## Training

# %%
model_name='CNN_2' # To compare models, you can give them different names

pweight='./weights/weights_' + model_name  + '.keras'

if not os.path.exists('./weights'):
  os.mkdir('./weights')

## EXPLORE VALUES AND FIND A GOOD SET
b_size = 3 # batch size
val_split = 0.2 # percentage of samples used for validation (e.g. 0.5)
ep = 20 # number of epochs

# %% [markdown]
# ## AlexNet Inspired Model

# %%
input_shape = x_train.shape[1:4] #(28,28,1)
model = Sequential()


model.add(Conv2D(32, kernel_size=(3, 3), strides=1, activation='relu', input_shape=(28, 28, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Conv2D(64, kernel_size=(3, 3), strides=1, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_cls, activation='softmax'))

model.compile(loss = categorical_crossentropy,
              optimizer=Adadelta(),
              metrics=['accuracy'])

model.summary()

checkpointer = ModelCheckpoint(filepath=pweight, verbose=1, save_best_only=True)
callbacks_list = [checkpointer] # explore adding other callbacks such as ReduceLROnPlateau, EarlyStopping

history=model.fit(x_train, y_train,
                        epochs=ep,
                        batch_size=b_size,
                        verbose=1,
                        shuffle=True,
                        validation_split = val_split,
                        callbacks=callbacks_list)

print('CNN_1 weights saved in ' + pweight)

# Plot loss vs epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# Plot accuracy vs epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 26, 26, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 13, 13, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,275,530 (4.87 MB)
#  Trainable params: 1,275,338 (4.87 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/20
# 15998/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1221 - loss: 2.6442
# Epoch 1: val_loss improved from inf to 2.15312, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 102s 6ms/step - accuracy: 0.1221 - loss: 2.6441 - val_accuracy: 0.2307 - val_loss: 2.1531
# Epoch 2/20
# 15994/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1943 - loss: 2.2257
# Epoch 2: val_loss improved from 2.15312 to 2.00602, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 100s 6ms/step - accuracy: 0.1943 - loss: 2.2257 - val_accuracy: 0.3119 - val_loss: 2.0060
# Epoch 3/20
# 15994/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2566 - loss: 2.0870
# Epoch 3: val_loss improved from 2.00602 to 1.86183, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 93s 6ms/step - accuracy: 0.2566 - loss: 2.0870 - val_accuracy: 0.3714 - val_loss: 1.8618
# Epoch 4/20
# 15997/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3081 - loss: 1.9697
# Epoch 4: val_loss improved from 1.86183 to 1.72645, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 95s 6ms/step - accuracy: 0.3081 - loss: 1.9697 - val_accuracy: 0.4251 - val_loss: 1.7264
# Epoch 5/20
# 15997/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3459 - loss: 1.8671
# Epoch 5: val_loss improved from 1.72645 to 1.61661, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 99s 6ms/step - accuracy: 0.3459 - loss: 1.8671 - val_accuracy: 0.4643 - val_loss: 1.6166
# Epoch 6/20
# 15992/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3787 - loss: 1.7757
# Epoch 6: val_loss improved from 1.61661 to 1.51754, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 112s 7ms/step - accuracy: 0.3787 - loss: 1.7757 - val_accuracy: 0.4986 - val_loss: 1.5175
# Epoch 7/20
# 15994/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4101 - loss: 1.6951
# Epoch 7: val_loss improved from 1.51754 to 1.43490, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 87s 5ms/step - accuracy: 0.4101 - loss: 1.6951 - val_accuracy: 0.5267 - val_loss: 1.4349
# Epoch 8/20
# 15992/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4405 - loss: 1.6175
# Epoch 8: val_loss improved from 1.43490 to 1.36317, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 95s 6ms/step - accuracy: 0.4405 - loss: 1.6175 - val_accuracy: 0.5495 - val_loss: 1.3632
# Epoch 9/20
# 15993/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4594 - loss: 1.5622
# Epoch 9: val_loss improved from 1.36317 to 1.29916, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 98s 6ms/step - accuracy: 0.4594 - loss: 1.5622 - val_accuracy: 0.5727 - val_loss: 1.2992
# Epoch 10/20
# 15996/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4806 - loss: 1.5047
# Epoch 10: val_loss improved from 1.29916 to 1.24064, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 90s 6ms/step - accuracy: 0.4806 - loss: 1.5047 - val_accuracy: 0.5922 - val_loss: 1.2406
# Epoch 11/20
# 15998/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5017 - loss: 1.4515
# Epoch 11: val_loss improved from 1.24064 to 1.19178, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 93s 6ms/step - accuracy: 0.5017 - loss: 1.4515 - val_accuracy: 0.6072 - val_loss: 1.1918
# Epoch 12/20
# 15995/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5192 - loss: 1.4069
# Epoch 12: val_loss improved from 1.19178 to 1.14829, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 95s 6ms/step - accuracy: 0.5192 - loss: 1.4069 - val_accuracy: 0.6204 - val_loss: 1.1483
# Epoch 13/20
# 15998/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5372 - loss: 1.3473
# Epoch 13: val_loss improved from 1.14829 to 1.10964, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 96s 6ms/step - accuracy: 0.5372 - loss: 1.3473 - val_accuracy: 0.6348 - val_loss: 1.1096
# Epoch 14/20
# 15995/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5480 - loss: 1.3305
# Epoch 14: val_loss improved from 1.10964 to 1.07049, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 97s 6ms/step - accuracy: 0.5480 - loss: 1.3305 - val_accuracy: 0.6465 - val_loss: 1.0705
# Epoch 15/20
# 15994/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5658 - loss: 1.2817
# Epoch 15: val_loss improved from 1.07049 to 1.03355, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 96s 6ms/step - accuracy: 0.5658 - loss: 1.2817 - val_accuracy: 0.6597 - val_loss: 1.0336
# Epoch 16/20
# 15994/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5780 - loss: 1.2560
# Epoch 16: val_loss improved from 1.03355 to 1.00546, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 97s 6ms/step - accuracy: 0.5780 - loss: 1.2559 - val_accuracy: 0.6717 - val_loss: 1.0055
# Epoch 17/20
# 15994/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5835 - loss: 1.2248
# Epoch 17: val_loss improved from 1.00546 to 0.97644, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 104s 6ms/step - accuracy: 0.5835 - loss: 1.2248 - val_accuracy: 0.6792 - val_loss: 0.9764
# Epoch 18/20
# 15994/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5999 - loss: 1.1948
# Epoch 18: val_loss improved from 0.97644 to 0.94888, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 96s 6ms/step - accuracy: 0.5999 - loss: 1.1948 - val_accuracy: 0.6871 - val_loss: 0.9489
# Epoch 19/20
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6068 - loss: 1.1646
# Epoch 19: val_loss improved from 0.94888 to 0.92721, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 108s 7ms/step - accuracy: 0.6068 - loss: 1.1646 - val_accuracy: 0.6965 - val_loss: 0.9272
# Epoch 20/20
# 15995/16000 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6245 - loss: 1.1304
# Epoch 20: val_loss improved from 0.92721 to 0.90483, saving model to ./weights/weights_CNN_2.keras
# 16000/16000 ━━━━━━━━━━━━━━━━━━━━ 110s 7ms/step - accuracy: 0.6245 - loss: 1.1304 - val_accuracy: 0.7027 - val_loss: 0.9048
# CNN_1 weights saved in ./weights/weights_CNN_2.keras

# %% [markdown]
# ## Make predictions in test set

# %%
from keras.models import load_model

## LOAD DATA
data = np.load('./MNIST_CorrNoise.npz')

x_test = data['x_test']
y_test = data['y_test']

num_cls = len(np.unique(y_test))
print('Number of classes: ' + str(num_cls))

# RESHAPE and standarize
x_test = np.expand_dims(x_test/255,axis=3)

print('Shape of x_train: '+str(x_test.shape)+'\n')

## Define model parameters
model_name='CNN_2' # To compare models, you can give them different names
pweight='./weights/weights_' + model_name  + '.keras'

model = load_model(pweight)
y_pred = model.predict(x_test)
# Convert predicted probabilities to class indices
y_pred_classes = np.argmax(y_pred, axis=1)

# Ensure y_test is also in class indices (not one-hot encoded)
if len(y_test.shape) > 1:  # If y_test is one-hot encoded
    y_test = np.argmax(y_test, axis=1)

Acc_pred = sum(y_pred_classes == y_test) / len(y_test)
#Acc_pred = sum(y_pred == y_test)/len(y_test)

print('Accuracy in test set is: '+str(Acc_pred))
# Out:
# Number of classes: 10
# Shape of x_train: (10000, 28, 28, 1)
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Accuracy in test set is: 0.6885
